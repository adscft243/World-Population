# %%
dt <- read.csv('world_population.csv')

# %%
fit <- lm(dt$Yearly.Change ~ dt$Fert..Rate + dt$Med..Age)

# %%
summary(fit)
# Out:
# Call:
# lm(formula = dt$Yearly.Change ~ dt$Fert..Rate + dt$Med..Age)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -2.36483 -0.25625  0.03176  0.25355  2.78156
#
# Coefficients:
#                Estimate Std. Error t value Pr(>|t|)
# (Intercept)    2.289578   0.450090   5.087 8.42e-07 ***
# dt$Fert..Rate  0.310920   0.066515   4.674 5.44e-06 ***
# dt$Med..Age   -0.062906   0.009221  -6.822 1.07e-10 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.5595 on 198 degrees of freedom
# Multiple R-squared:  0.7399,	Adjusted R-squared:  0.7372
# F-statistic: 281.6 on 2 and 198 DF,  p-value: < 2.2e-16

# %%
plot(fit$residuals)
# Out:
# plot without title

# %%
hist(fit$residuals)
# Out:
# Plot with title “Histogram of fit$residuals”
